# %%
import simsopt

# %%
from neorl import PPOES
from neorl import CreateEnvironment

def Sphere(individual):
    """Sphere test objective function.
            F(x) = sum_{i=1}^d xi^2
            d=1,2,3,...
            Range: [-100,100]
            Minima: 0
    """
    y=sum(x**2 for x in individual)
    return y


#Setup the parameter space (d=5)
nx=5
BOUNDS={}
for i in range(1,nx+1):
    BOUNDS['x'+str(i)]=['float', -100, 100]
    

if __name__=='__main__':  #use this block for parallel PPO!
    #create an enviroment class for RL/PPO
    env=CreateEnvironment(method='ppo', fit=Sphere, ncores=1,  
                          bounds=BOUNDS, mode='min', episode_length=50)
    
    #change hyperparameters of PPO/ES if you like (defaults should be good to start with)
    h={'cxpb': 0.8,
       'mutpb': 0.2,
       'n_steps': 24,
       'lam': 1.0}
    
    #Important: `mode` in CreateEnvironment and `mode` in PPOES must be consistent
    #fit is needed to be passed again for ES, must be same as the one used in env
    ppoes=PPOES(mode='min', fit=Sphere, 
                env=env, npop_rl=4, init_pop_rl=True, 
                bounds=BOUNDS, hyperparam=h, seed=1)
    #first run RL for some timesteps
    rl=ppoes.learn(total_timesteps=2000, verbose=True)
    #second run ES, which will use RL data for guidance
    ppoes_x, ppoes_y, ppoes_hist=ppoes.evolute(ngen=20, ncores=1, verbose=True) #ncores for ES
# Out:
# 	    NEORL: NeuroEvolution Optimisation with Reinforcement Learning
# 			 ███╗   ██╗███████╗ ██████╗ ██████╗ ██╗
# 			 ████╗  ██║██╔════╝██╔═══██╗██╔══██╗██║
# 			 ██╔██╗ ██║█████╗  ██║   ██║██████╔╝██║
# 			 ██║╚██╗██║██╔══╝  ██║   ██║██╔══██╗██║
# 			 ██║ ╚████║███████╗╚██████╔╝██║  ██║███████╗
# 			 ╚═╝  ╚═══╝╚══════╝ ╚═════╝ ╚═╝  ╚═╝╚══════╝
# Copyright © 2021 Exelon Corporation (https://www.exeloncorp.com/) in collaboration with
#              MIT Nuclear Science and Engineering (https://web.mit.edu/nse/)
#                              All Rights Reserved
#
#
#
# ---------------------------------------------------------------------------------
# ------------------------------- PPO-ES is Running -------------------------------
# ---------------------------------------------------------------------------------
# Serial RL is running with 1 core
# --warning: Problem mode defined in the RL enviroment is min
# --warning: Problem mode defined in the PPOES class is min
# --warning: Both problem modes match
# ------------------------------- Part I: PPO is collecting data -------------------------------
# Wrapping the env in a DummyVecEnv.
# Adding SHARED layer number -- 0 -- with  {'vf': [64, 64], 'pi': [64, 64]} nodes
# Adding NON-SHARED layer number -- 0 -- with  {'vf': [64, 64], 'pi': [64, 64]} nodes
# Adding NON-SHARED layer number -- 1 -- with  {'vf': [64, 64], 'pi': [64, 64]} nodes
# Adding SHARED layer number -- 0 -- with  {'vf': [64, 64], 'pi': [64, 64]} nodes
# Adding NON-SHARED layer number -- 0 -- with  {'vf': [64, 64], 'pi': [64, 64]} nodes
# Adding NON-SHARED layer number -- 1 -- with  {'vf': [64, 64], 'pi': [64, 64]} nodes
# --------------------------------------
# | approxkl           | 8.168915e-08  |
# | clipfrac           | 0.0           |
# | explained_variance | -5.96e-07     |
# | fps                | 106           |
# | n_updates          | 1             |
# | policy_entropy     | 7.094678      |
# | policy_loss        | -0.0001776541 |
# | serial_timesteps   | 24            |
# | time_elapsed       | 1.14e-05      |
# | total_timesteps    | 24            |
# | value_loss         | 62256250000.0 |
# --------------------------------------
# --------------------------------------
# | approxkl           | 0.0004437017  |
# | clipfrac           | 0.0           |
# | explained_variance | 1.13e-06      |
# | fps                | 592           |
# | n_updates          | 2             |
# | policy_entropy     | 7.0959196     |
# | policy_loss        | 0.0006832087  |
# | serial_timesteps   | 48            |
# | time_elapsed       | 0.228         |
# | total_timesteps    | 48            |
# | value_loss         | 64175310000.0 |
# --------------------------------------
# --------------------------------------
# | approxkl           | 5.2260926e-05 |
# | clipfrac           | 0.0           |
# | explained_variance | -2.38e-07     |
# | fps                | 612           |
# | n_updates          | 3             |
# | policy_entropy     | 7.0961394     |
# | policy_loss        | -0.0005653719 |
# | serial_timesteps   | 72            |
# | time_elapsed       | 0.27          |
# | total_timesteps    | 72            |
# | value_loss         | 51546160000.0 |
# --------------------------------------
# --------------------------------------
# | approxkl           | 0.00077298767 |
# | clipfrac           | 0.004166667   |
# | explained_variance | 6.56e-07      |
# | fps                | 634           |
# | n_updates          | 4             |
# | policy_entropy     | 7.0909386     |
# | policy_loss        | -0.0060902843 |
# | serial_timesteps   | 96            |
# | time_elapsed       | 0.311         |
# | total_timesteps    | 96            |
# | value_loss         | 62737195000.0 |
# --------------------------------------
# --------------------------------------
# | approxkl           | 0.00065021904 |
# | clipfrac           | 0.0           |
# | explained_variance | 2.98e-06      |
# | fps                | 635           |
# | n_updates          | 5             |
# | policy_entropy     | 7.086264      |
# | policy_loss        | 0.0015287176  |
# | serial_timesteps   | 120           |
# | time_elapsed       | 0.35          |
# | total_timesteps    | 120           |
# | value_loss         | 36605583000.0 |
# --------------------------------------
# --------------------------------------
# | approxkl           | 0.00013245209 |
# | clipfrac           | 0.0           |
# | explained_variance | -4.77e-07     |
# | fps                | 638           |
# | n_updates          | 6             |
# | policy_entropy     | 7.0857477     |
# | policy_loss        | -0.0018322415 |
# | serial_timesteps   | 144           |
# | time_elapsed       | 0.389         |
# | total_timesteps    | 144           |
# | value_loss         | 61410685000.0 |
# --------------------------------------
# --------------------------------------
# | approxkl           | 0.0017884364  |
# | clipfrac           | 0.0125        |
# | explained_variance | 3.58e-07      |
# | fps                | 635           |
# | n_updates          | 7             |
# | policy_entropy     | 7.0873594     |
# | policy_loss        | 0.015996356   |
# | serial_timesteps   | 168           |
# | time_elapsed       | 0.428         |
# | total_timesteps    | 168           |
# | value_loss         | 29862720000.0 |
# --------------------------------------
# --------------------------------------
# | approxkl           | 0.0011790576  |
# | clipfrac           | 0.020833334   |
# | explained_variance | 4.77e-07      |
# | fps                | 635           |
# | n_updates          | 8             |
# | policy_entropy     | 7.0889235     |
# | policy_loss        | -0.0061838054 |
# | serial_timesteps   | 192           |
# | time_elapsed       | 0.468         |
# | total_timesteps    | 192           |
# | value_loss         | 48185500000.0 |
# --------------------------------------
# --------------------------------------
# | approxkl           | 0.0004559157  |
# | clipfrac           | 0.0           |
# | explained_variance | 2.09e-06      |
# | fps                | 631           |
# | n_updates          | 9             |
# | policy_entropy     | 7.085037      |
# | policy_loss        | -0.0037338804 |
# | serial_timesteps   | 216           |
# | time_elapsed       | 0.507         |
# | total_timesteps    | 216           |
# | value_loss         | 20582740000.0 |
# --------------------------------------
# --------------------------------------
# | approxkl           | 0.00015981849 |
# | clipfrac           | 0.0           |
# | explained_variance | -2.74e-06     |
# | fps                | 633           |
# | n_updates          | 10            |
# | policy_entropy     | 7.085332      |
# | policy_loss        | -0.0018806566 |
# | serial_timesteps   | 240           |
# | time_elapsed       | 0.546         |
# | total_timesteps    | 240           |
# | value_loss         | 47051366000.0 |
# --------------------------------------
# --------------------------------------
# | approxkl           | 0.0005440706  |
# | clipfrac           | 0.004166667   |
# | explained_variance | 1.85e-06      |
# | fps                | 637           |
# | n_updates          | 11            |
# | policy_entropy     | 7.0808105     |
# | policy_loss        | -0.0048162155 |
# | serial_timesteps   | 264           |
# | time_elapsed       | 0.586         |
# | total_timesteps    | 264           |
# | value_loss         | 15416784000.0 |
# --------------------------------------
# --------------------------------------
# | approxkl           | 0.0017450713  |
# | clipfrac           | 0.0125        |
# | explained_variance | 5.96e-07      |
# | fps                | 634           |
# | n_updates          | 12            |
# | policy_entropy     | 7.080046      |
# | policy_loss        | -0.013180673  |
# | serial_timesteps   | 288           |
# | time_elapsed       | 0.625         |
# | total_timesteps    | 288           |
# | value_loss         | 62480843000.0 |
# --------------------------------------
# --------------------------------------
# | approxkl           | 0.00074162334 |
# | clipfrac           | 0.0125        |
# | explained_variance | 2.09e-06      |
# | fps                | 636           |
# | n_updates          | 13            |
# | policy_entropy     | 7.0794096     |
# | policy_loss        | -0.009817948  |
# | serial_timesteps   | 312           |
# | time_elapsed       | 0.664         |
# | total_timesteps    | 312           |
# | value_loss         | 16146478000.0 |
# --------------------------------------
# --------------------------------------
# | approxkl           | 0.00065880746 |
# | clipfrac           | 0.0           |
# | explained_variance | 3.52e-06      |
# | fps                | 635           |
# | n_updates          | 14            |
# | policy_entropy     | 7.0859475     |
# | policy_loss        | 0.004521028   |
# | serial_timesteps   | 336           |
# | time_elapsed       | 0.703         |
# | total_timesteps    | 336           |
# | value_loss         | 45963030000.0 |
# --------------------------------------
# ---------------------------------------
# | approxkl           | 0.00040092715  |
# | clipfrac           | 0.0            |
# | explained_variance | -1.79e-06      |
# | fps                | 639            |
# | n_updates          | 15             |
# | policy_entropy     | 7.0907087      |
# | policy_loss        | -0.00047587338 |
# | serial_timesteps   | 360            |
# | time_elapsed       | 0.742          |
# | total_timesteps    | 360            |
# | value_loss         | 22198688000.0  |
# ---------------------------------------
# --------------------------------------
# | approxkl           | 0.00023195885 |
# | clipfrac           | 0.0           |
# | explained_variance | -3.58e-06     |
# | fps                | 641           |
# | n_updates          | 16            |
# | policy_entropy     | 7.0923567     |
# | policy_loss        | -0.0028489183 |
# | serial_timesteps   | 384           |
# | time_elapsed       | 0.781         |
# | total_timesteps    | 384           |
# | value_loss         | 50184397000.0 |
# --------------------------------------
# --------------------------------------
# | approxkl           | 0.0017728467  |
# | clipfrac           | 0.0           |
# | explained_variance | 3.1e-06       |
# | fps                | 635           |
# | n_updates          | 17            |
# | policy_entropy     | 7.0866013     |
# | policy_loss        | 0.001868623   |
# | serial_timesteps   | 408           |
# | time_elapsed       | 0.82          |
# | total_timesteps    | 408           |
# | value_loss         | 21558155000.0 |
# --------------------------------------
# --------------------------------------
# | approxkl           | 0.0003448153  |
# | clipfrac           | 0.0           |
# | explained_variance | 4.77e-07      |
# | fps                | 640           |
# | n_updates          | 18            |
# | policy_entropy     | 7.0858064     |
# | policy_loss        | -0.005839206  |
# | serial_timesteps   | 432           |
# | time_elapsed       | 0.859         |
# | total_timesteps    | 432           |
# | value_loss         | 76991220000.0 |
# --------------------------------------
# --------------------------------------
# | approxkl           | 0.0026003253  |
# | clipfrac           | 0.03333333    |
# | explained_variance | -1.91e-06     |
# | fps                | 636           |
# | n_updates          | 19            |
# | policy_entropy     | 7.092374      |
# | policy_loss        | -0.021568934  |
# | serial_timesteps   | 456           |
# | time_elapsed       | 0.898         |
# | total_timesteps    | 456           |
# | value_loss         | 27527440000.0 |
# --------------------------------------
# --------------------------------------
# | approxkl           | 0.0007113776  |
# | clipfrac           | 0.0           |
# | explained_variance | -1.19e-07     |
# | fps                | 636           |
# | n_updates          | 20            |
# | policy_entropy     | 7.092537      |
# | policy_loss        | -0.00864069   |
# | serial_timesteps   | 480           |
# | time_elapsed       | 0.938         |
# | total_timesteps    | 480           |
# | value_loss         | 50027160000.0 |
# --------------------------------------
# --------------------------------------
# | approxkl           | 0.00224709    |
# | clipfrac           | 0.0125        |
# | explained_variance | 1.07e-06      |
# | fps                | 641           |
# | n_updates          | 21            |
# | policy_entropy     | 7.092337      |
# | policy_loss        | -0.017238613  |
# | serial_timesteps   | 504           |
# | time_elapsed       | 0.977         |
# | total_timesteps    | 504           |
# | value_loss         | 38508536000.0 |
# --------------------------------------
# --------------------------------------
# | approxkl           | 0.0010332798  |
# | clipfrac           | 0.0           |
# | explained_variance | -7.39e-06     |
# | fps                | 635           |
# | n_updates          | 22            |
# | policy_entropy     | 7.09226       |
# | policy_loss        | -0.0015718701 |
# | serial_timesteps   | 528           |
# | time_elapsed       | 1.02          |
# | total_timesteps    | 528           |
# | value_loss         | 37109326000.0 |
# --------------------------------------
# --------------------------------------
# | approxkl           | 0.00078901125 |
# | clipfrac           | 0.0           |
# | explained_variance | 2.98e-07      |
# | fps                | 633           |
# | n_updates          | 23            |
# | policy_entropy     | 7.0839605     |
# | policy_loss        | -0.0031564538 |
# | serial_timesteps   | 552           |
# | time_elapsed       | 1.05          |
# | total_timesteps    | 552           |
# | value_loss         | 57701356000.0 |
# --------------------------------------
# --------------------------------------
# | approxkl           | 0.0013267152  |
# | clipfrac           | 0.008333334   |
# | explained_variance | -3.7e-06      |
# | fps                | 641           |
# | n_updates          | 24            |
# | policy_entropy     | 7.0819597     |
# | policy_loss        | 0.0063238614  |
# | serial_timesteps   | 576           |
# | time_elapsed       | 1.09          |
# | total_timesteps    | 576           |
# | value_loss         | 79568945000.0 |
# --------------------------------------
# --------------------------------------
# | approxkl           | 0.000491992   |
# | clipfrac           | 0.0           |
# | explained_variance | -2.62e-06     |
# | fps                | 642           |
# | n_updates          | 25            |
# | policy_entropy     | 7.0823493     |
# | policy_loss        | 0.0008678857  |
# | serial_timesteps   | 600           |
# | time_elapsed       | 1.13          |
# | total_timesteps    | 600           |
# | value_loss         | 60520083000.0 |
# --------------------------------------
# --------------------------------------
# | approxkl           | 0.0019097815  |
# | clipfrac           | 0.016666668   |
# | explained_variance | -9.54e-07     |
# | fps                | 639           |
# | n_updates          | 26            |
# | policy_entropy     | 7.0801187     |
# | policy_loss        | -0.018531581  |
# | serial_timesteps   | 624           |
# | time_elapsed       | 1.17          |
# | total_timesteps    | 624           |
# | value_loss         | 59310660000.0 |
# --------------------------------------
# --------------------------------------
# | approxkl           | 0.0010476998  |
# | clipfrac           | 0.004166667   |
# | explained_variance | -5.96e-07     |
# | fps                | 642           |
# | n_updates          | 27            |
# | policy_entropy     | 7.0774546     |
# | policy_loss        | 0.0050099934  |
# | serial_timesteps   | 648           |
# | time_elapsed       | 1.21          |
# | total_timesteps    | 648           |
# | value_loss         | 66378970000.0 |
# --------------------------------------
# --------------------------------------
# | approxkl           | 0.004374199   |
# | clipfrac           | 0.05833333    |
# | explained_variance | -1.19e-07     |
# | fps                | 642           |
# | n_updates          | 28            |
# | policy_entropy     | 7.0743737     |
# | policy_loss        | -0.024278458  |
# | serial_timesteps   | 672           |
# | time_elapsed       | 1.25          |
# | total_timesteps    | 672           |
# | value_loss         | 36041335000.0 |
# --------------------------------------
# --------------------------------------
# | approxkl           | 0.0023344776  |
# | clipfrac           | 0.004166667   |
# | explained_variance | -9.54e-07     |
# | fps                | 642           |
# | n_updates          | 29            |
# | policy_entropy     | 7.073078      |
# | policy_loss        | -0.014836596  |
# | serial_timesteps   | 696           |
# | time_elapsed       | 1.29          |
# | total_timesteps    | 696           |
# | value_loss         | 51625173000.0 |
# --------------------------------------
# --------------------------------------
# | approxkl           | 0.0027315072  |
# | clipfrac           | 0.03333333    |
# | explained_variance | 5.42e-06      |
# | fps                | 629           |
# | n_updates          | 30            |
# | policy_entropy     | 7.0748725     |
# | policy_loss        | -0.0140182    |
# | serial_timesteps   | 720           |
# | time_elapsed       | 1.33          |
# | total_timesteps    | 720           |
# | value_loss         | 30259239000.0 |
# --------------------------------------
# --------------------------------------
# | approxkl           | 0.0035097222  |
# | clipfrac           | 0.033333335   |
# | explained_variance | -2.26e-06     |
# | fps                | 643           |
# | n_updates          | 31            |
# | policy_entropy     | 7.0765305     |
# | policy_loss        | -0.012190642  |
# | serial_timesteps   | 744           |
# | time_elapsed       | 1.37          |
# | total_timesteps    | 744           |
# | value_loss         | 40311840000.0 |
# --------------------------------------
# --------------------------------------
# | approxkl           | 0.0004180795  |
# | clipfrac           | 0.0           |
# | explained_variance | 3.52e-06      |
# | fps                | 642           |
# | n_updates          | 32            |
# | policy_entropy     | 7.0701246     |
# | policy_loss        | 0.0021460212  |
# | serial_timesteps   | 768           |
# | time_elapsed       | 1.41          |
# | total_timesteps    | 768           |
# | value_loss         | 33995264000.0 |
# --------------------------------------
# --------------------------------------
# | approxkl           | 0.0010380645  |
# | clipfrac           | 0.004166667   |
# | explained_variance | -2.5e-06      |
# | fps                | 642           |
# | n_updates          | 33            |
# | policy_entropy     | 7.0711756     |
# | policy_loss        | -0.0040149097 |
# | serial_timesteps   | 792           |
# | time_elapsed       | 1.44          |
# | total_timesteps    | 792           |
# | value_loss         | 44349630000.0 |
# --------------------------------------
# --------------------------------------
# | approxkl           | 0.002407618   |
# | clipfrac           | 0.020833334   |
# | explained_variance | -3.58e-06     |
# | fps                | 639           |
# | n_updates          | 34            |
# | policy_entropy     | 7.067106      |
# | policy_loss        | -0.011159891  |
# | serial_timesteps   | 816           |
# | time_elapsed       | 1.48          |
# | total_timesteps    | 816           |
# | value_loss         | 20841760000.0 |
# --------------------------------------
# --------------------------------------
# | approxkl           | 0.0021065262  |
# | clipfrac           | 0.016666668   |
# | explained_variance | -4.53e-06     |
# | fps                | 642           |
# | n_updates          | 35            |
# | policy_entropy     | 7.0611525     |
# | policy_loss        | -0.005867756  |
# | serial_timesteps   | 840           |
# | time_elapsed       | 1.52          |
# | total_timesteps    | 840           |
# | value_loss         | 60581425000.0 |
# --------------------------------------
# --------------------------------------
# | approxkl           | 0.002355645   |
# | clipfrac           | 0.0125        |
# | explained_variance | 8.17e-06      |
# | fps                | 636           |
# | n_updates          | 36            |
# | policy_entropy     | 7.0615096     |
# | policy_loss        | -0.0034367242 |
# | serial_timesteps   | 864           |
# | time_elapsed       | 1.56          |
# | total_timesteps    | 864           |
# | value_loss         | 17764473000.0 |
# --------------------------------------
# --------------------------------------
# | approxkl           | 0.005219355   |
# | clipfrac           | 0.06666666    |
# | explained_variance | -6.91e-06     |
# | fps                | 640           |
# | n_updates          | 37            |
# | policy_entropy     | 7.0635056     |
# | policy_loss        | 0.0016177744  |
# | serial_timesteps   | 888           |
# | time_elapsed       | 1.6           |
# | total_timesteps    | 888           |
# | value_loss         | 62249970000.0 |
# --------------------------------------
# --------------------------------------
# | approxkl           | 0.005456575   |
# | clipfrac           | 0.0625        |
# | explained_variance | 1.31e-05      |
# | fps                | 638           |
# | n_updates          | 38            |
# | policy_entropy     | 7.072338      |
# | policy_loss        | -0.011160644  |
# | serial_timesteps   | 912           |
# | time_elapsed       | 1.64          |
# | total_timesteps    | 912           |
# | value_loss         | 17894445000.0 |
# --------------------------------------
# --------------------------------------
# | approxkl           | 0.0059498856  |
# | clipfrac           | 0.079166666   |
# | explained_variance | -1.31e-06     |
# | fps                | 642           |
# | n_updates          | 39            |
# | policy_entropy     | 7.085067      |
# | policy_loss        | -0.03599382   |
# | serial_timesteps   | 936           |
# | time_elapsed       | 1.68          |
# | total_timesteps    | 936           |
# | value_loss         | 75872910000.0 |
# --------------------------------------
# --------------------------------------
# | approxkl           | 0.0018325042  |
# | clipfrac           | 0.008333334   |
# | explained_variance | 2.8e-06       |
# | fps                | 641           |
# | n_updates          | 40            |
# | policy_entropy     | 7.0990896     |
# | policy_loss        | 0.010034479   |
# | serial_timesteps   | 960           |
# | time_elapsed       | 1.72          |
# | total_timesteps    | 960           |
# | value_loss         | 17935530000.0 |
# --------------------------------------
# --------------------------------------
# | approxkl           | 0.001581921   |
# | clipfrac           | 0.004166667   |
# | explained_variance | -2.5e-06      |
# | fps                | 644           |
# | n_updates          | 41            |
# | policy_entropy     | 7.102051      |
# | policy_loss        | -0.015757006  |
# | serial_timesteps   | 984           |
# | time_elapsed       | 1.76          |
# | total_timesteps    | 984           |
# | value_loss         | 60939200000.0 |
# --------------------------------------
# --------------------------------------
# | approxkl           | 0.0010422893  |
# | clipfrac           | 0.004166667   |
# | explained_variance | 8.94e-06      |
# | fps                | 642           |
# | n_updates          | 42            |
# | policy_entropy     | 7.099767      |
# | policy_loss        | -0.012453636  |
# | serial_timesteps   | 1008          |
# | time_elapsed       | 1.79          |
# | total_timesteps    | 1008          |
# | value_loss         | 18294841000.0 |
# --------------------------------------
# --------------------------------------
# | approxkl           | 0.0015517205  |
# | clipfrac           | 0.0125        |
# | explained_variance | -5.36e-06     |
# | fps                | 642           |
# | n_updates          | 43            |
# | policy_entropy     | 7.1017747     |
# | policy_loss        | -0.011168754  |
# | serial_timesteps   | 1032          |
# | time_elapsed       | 1.83          |
# | total_timesteps    | 1032          |
# | value_loss         | 66998292000.0 |
# --------------------------------------
# --------------------------------------
# | approxkl           | 0.0023237537  |
# | clipfrac           | 0.020833334   |
# | explained_variance | 2.09e-06      |
# | fps                | 642           |
# | n_updates          | 44            |
# | policy_entropy     | 7.1075354     |
# | policy_loss        | -0.0052305893 |
# | serial_timesteps   | 1056          |
# | time_elapsed       | 1.87          |
# | total_timesteps    | 1056          |
# | value_loss         | 31426734000.0 |
# --------------------------------------
# --------------------------------------
# | approxkl           | 0.0035153374  |
# | clipfrac           | 0.0375        |
# | explained_variance | -7.39e-06     |
# | fps                | 638           |
# | n_updates          | 45            |
# | policy_entropy     | 7.1038117     |
# | policy_loss        | -0.028431926  |
# | serial_timesteps   | 1080          |
# | time_elapsed       | 1.91          |
# | total_timesteps    | 1080          |
# | value_loss         | 69380760000.0 |
# --------------------------------------
# --------------------------------------
# | approxkl           | 0.0012061166  |
# | clipfrac           | 0.0125        |
# | explained_variance | -3.22e-06     |
# | fps                | 636           |
# | n_updates          | 46            |
# | policy_entropy     | 7.102806      |
# | policy_loss        | -0.008503812  |
# | serial_timesteps   | 1104          |
# | time_elapsed       | 1.95          |
# | total_timesteps    | 1104          |
# | value_loss         | 37108100000.0 |
# --------------------------------------
# --------------------------------------
# | approxkl           | 0.004098316   |
# | clipfrac           | 0.045833334   |
# | explained_variance | 5.25e-06      |
# | fps                | 640           |
# | n_updates          | 47            |
# | policy_entropy     | 7.100456      |
# | policy_loss        | -0.025376106  |
# | serial_timesteps   | 1128          |
# | time_elapsed       | 1.99          |
# | total_timesteps    | 1128          |
# | value_loss         | 52219750000.0 |
# --------------------------------------
# --------------------------------------
# | approxkl           | 0.00299701    |
# | clipfrac           | 0.0375        |
# | explained_variance | 2.38e-06      |
# | fps                | 640           |
# | n_updates          | 48            |
# | policy_entropy     | 7.0953536     |
# | policy_loss        | -0.024232185  |
# | serial_timesteps   | 1152          |
# | time_elapsed       | 2.03          |
# | total_timesteps    | 1152          |
# | value_loss         | 51879560000.0 |
# --------------------------------------
# ---------------------------------------
# | approxkl           | 0.0013799976   |
# | clipfrac           | 0.008333334    |
# | explained_variance | 1.79e-06       |
# | fps                | 642            |
# | n_updates          | 49             |
# | policy_entropy     | 7.09486        |
# | policy_loss        | -4.6581215e-05 |
# | serial_timesteps   | 1176           |
# | time_elapsed       | 2.07           |
# | total_timesteps    | 1176           |
# | value_loss         | 76203065000.0  |
# ---------------------------------------
# --------------------------------------
# | approxkl           | 0.0015350174  |
# | clipfrac           | 0.0125        |
# | explained_variance | -1.62e-05     |
# | fps                | 642           |
# | n_updates          | 50            |
# | policy_entropy     | 7.103424      |
# | policy_loss        | -0.008024702  |
# | serial_timesteps   | 1200          |
# | time_elapsed       | 2.11          |
# | total_timesteps    | 1200          |
# | value_loss         | 47739757000.0 |
# --------------------------------------
# --------------------------------------
# | approxkl           | 0.0036958163  |
# | clipfrac           | 0.03333333    |
# | explained_variance | 6.62e-06      |
# | fps                | 642           |
# | n_updates          | 51            |
# | policy_entropy     | 7.1030717     |
# | policy_loss        | -0.025078053  |
# | serial_timesteps   | 1224          |
# | time_elapsed       | 2.14          |
# | total_timesteps    | 1224          |
# | value_loss         | 44881584000.0 |
# --------------------------------------
# --------------------------------------
# | approxkl           | 0.0039889663  |
# | clipfrac           | 0.05          |
# | explained_variance | 1.31e-06      |
# | fps                | 603           |
# | n_updates          | 52            |
# | policy_entropy     | 7.090879      |
# | policy_loss        | -0.022851665  |
# | serial_timesteps   | 1248          |
# | time_elapsed       | 2.18          |
# | total_timesteps    | 1248          |
# | value_loss         | 38767837000.0 |
# --------------------------------------
# --------------------------------------
# | approxkl           | 0.001963598   |
# | clipfrac           | 0.0125        |
# | explained_variance | 6.2e-06       |
# | fps                | 635           |
# | n_updates          | 53            |
# | policy_entropy     | 7.081109      |
# | policy_loss        | -0.01727426   |
# | serial_timesteps   | 1272          |
# | time_elapsed       | 2.22          |
# | total_timesteps    | 1272          |
# | value_loss         | 31705120000.0 |
# --------------------------------------
# --------------------------------------
# | approxkl           | 0.005098401   |
# | clipfrac           | 0.07083333    |
# | explained_variance | -5.96e-07     |
# | fps                | 563           |
# | n_updates          | 54            |
# | policy_entropy     | 7.072666      |
# | policy_loss        | -0.035229027  |
# | serial_timesteps   | 1296          |
# | time_elapsed       | 2.26          |
# | total_timesteps    | 1296          |
# | value_loss         | 73630410000.0 |
# --------------------------------------
# --------------------------------------
# | approxkl           | 0.004670911   |
# | clipfrac           | 0.0625        |
# | explained_variance | 6.97e-06      |
# | fps                | 633           |
# | n_updates          | 55            |
# | policy_entropy     | 7.0718527     |
# | policy_loss        | -0.024698853  |
# | serial_timesteps   | 1320          |
# | time_elapsed       | 2.31          |
# | total_timesteps    | 1320          |
# | value_loss         | 39822860000.0 |
# --------------------------------------
# --------------------------------------
# | approxkl           | 0.004837155   |
# | clipfrac           | 0.05833333    |
# | explained_variance | 2.03e-06      |
# | fps                | 638           |
# | n_updates          | 56            |
# | policy_entropy     | 7.0555396     |
# | policy_loss        | -0.021160182  |
# | serial_timesteps   | 1344          |
# | time_elapsed       | 2.35          |
# | total_timesteps    | 1344          |
# | value_loss         | 78040450000.0 |
# --------------------------------------
# --------------------------------------
# | approxkl           | 0.0040289843  |
# | clipfrac           | 0.058333326   |
# | explained_variance | 1.14e-05      |
# | fps                | 639           |
# | n_updates          | 57            |
# | policy_entropy     | 7.055936      |
# | policy_loss        | -0.026340414  |
# | serial_timesteps   | 1368          |
# | time_elapsed       | 2.39          |
# | total_timesteps    | 1368          |
# | value_loss         | 34376106000.0 |
# --------------------------------------
# --------------------------------------
# | approxkl           | 0.003761402   |
# | clipfrac           | 0.029166665   |
# | explained_variance | 5.9e-06       |
# | fps                | 641           |
# | n_updates          | 58            |
# | policy_entropy     | 7.0542436     |
# | policy_loss        | -0.007458179  |
# | serial_timesteps   | 1392          |
# | time_elapsed       | 2.43          |
# | total_timesteps    | 1392          |
# | value_loss         | 57132655000.0 |
# --------------------------------------
# --------------------------------------
# | approxkl           | 0.002646146   |
# | clipfrac           | 0.025         |
# | explained_variance | 7.75e-06      |
# | fps                | 643           |
# | n_updates          | 59            |
# | policy_entropy     | 7.0578017     |
# | policy_loss        | -0.020180356  |
# | serial_timesteps   | 1416          |
# | time_elapsed       | 2.46          |
# | total_timesteps    | 1416          |
# | value_loss         | 20788480000.0 |
# --------------------------------------
# --------------------------------------
# | approxkl           | 0.0015075123  |
# | clipfrac           | 0.008333334   |
# | explained_variance | -4.17e-06     |
# | fps                | 639           |
# | n_updates          | 60            |
# | policy_entropy     | 7.0526457     |
# | policy_loss        | -0.0013151772 |
# | serial_timesteps   | 1440          |
# | time_elapsed       | 2.5           |
# | total_timesteps    | 1440          |
# | value_loss         | 59985540000.0 |
# --------------------------------------
# --------------------------------------
# | approxkl           | 0.0013868163  |
# | clipfrac           | 0.004166667   |
# | explained_variance | 2.22e-05      |
# | fps                | 642           |
# | n_updates          | 61            |
# | policy_entropy     | 7.04953       |
# | policy_loss        | -0.008284077  |
# | serial_timesteps   | 1464          |
# | time_elapsed       | 2.54          |
# | total_timesteps    | 1464          |
# | value_loss         | 16673729000.0 |
# --------------------------------------
# --------------------------------------
# | approxkl           | 0.0037461433  |
# | clipfrac           | 0.0625        |
# | explained_variance | -2.5e-06      |
# | fps                | 615           |
# | n_updates          | 62            |
# | policy_entropy     | 7.0474944     |
# | policy_loss        | -0.013895335  |
# | serial_timesteps   | 1488          |
# | time_elapsed       | 2.58          |
# | total_timesteps    | 1488          |
# | value_loss         | 65718575000.0 |
# --------------------------------------
# --------------------------------------
# | approxkl           | 0.0014677048  |
# | clipfrac           | 0.0125        |
# | explained_variance | -1.38e-05     |
# | fps                | 626           |
# | n_updates          | 63            |
# | policy_entropy     | 7.050934      |
# | policy_loss        | -0.00101594   |
# | serial_timesteps   | 1512          |
# | time_elapsed       | 2.62          |
# | total_timesteps    | 1512          |
# | value_loss         | 19779926000.0 |
# --------------------------------------
# --------------------------------------
# | approxkl           | 0.005819186   |
# | clipfrac           | 0.07083333    |
# | explained_variance | 2.98e-06      |
# | fps                | 634           |
# | n_updates          | 64            |
# | policy_entropy     | 7.0438585     |
# | policy_loss        | -0.019872855  |
# | serial_timesteps   | 1536          |
# | time_elapsed       | 2.66          |
# | total_timesteps    | 1536          |
# | value_loss         | 57099760000.0 |
# --------------------------------------
# --------------------------------------
# | approxkl           | 0.0042770286  |
# | clipfrac           | 0.07083334    |
# | explained_variance | 1.37e-05      |
# | fps                | 640           |
# | n_updates          | 65            |
# | policy_entropy     | 7.037822      |
# | policy_loss        | -0.027451169  |
# | serial_timesteps   | 1560          |
# | time_elapsed       | 2.7           |
# | total_timesteps    | 1560          |
# | value_loss         | 15619963000.0 |
# --------------------------------------
# --------------------------------------
# | approxkl           | 0.0063530817  |
# | clipfrac           | 0.0875        |
# | explained_variance | -1.91e-06     |
# | fps                | 642           |
# | n_updates          | 66            |
# | policy_entropy     | 7.038681      |
# | policy_loss        | -0.039532408  |
# | serial_timesteps   | 1584          |
# | time_elapsed       | 2.74          |
# | total_timesteps    | 1584          |
# | value_loss         | 62858060000.0 |
# --------------------------------------
# --------------------------------------
# | approxkl           | 0.0032166545  |
# | clipfrac           | 0.041666664   |
# | explained_variance | -5.84e-06     |
# | fps                | 641           |
# | n_updates          | 67            |
# | policy_entropy     | 7.0338297     |
# | policy_loss        | -0.021344665  |
# | serial_timesteps   | 1608          |
# | time_elapsed       | 2.78          |
# | total_timesteps    | 1608          |
# | value_loss         | 20795453000.0 |
# --------------------------------------
# --------------------------------------
# | approxkl           | 0.0037137058  |
# | clipfrac           | 0.05          |
# | explained_variance | 4.89e-06      |
# | fps                | 641           |
# | n_updates          | 68            |
# | policy_entropy     | 7.035267      |
# | policy_loss        | -0.024519313  |
# | serial_timesteps   | 1632          |
# | time_elapsed       | 2.82          |
# | total_timesteps    | 1632          |
# | value_loss         | 48152105000.0 |
# --------------------------------------
# --------------------------------------
# | approxkl           | 0.0031293996  |
# | clipfrac           | 0.029166665   |
# | explained_variance | -6.32e-06     |
# | fps                | 641           |
# | n_updates          | 69            |
# | policy_entropy     | 7.031745      |
# | policy_loss        | -0.011959426  |
# | serial_timesteps   | 1656          |
# | time_elapsed       | 2.86          |
# | total_timesteps    | 1656          |
# | value_loss         | 32110900000.0 |
# --------------------------------------
# --------------------------------------
# | approxkl           | 0.006207559   |
# | clipfrac           | 0.079166666   |
# | explained_variance | -1.03e-05     |
# | fps                | 635           |
# | n_updates          | 70            |
# | policy_entropy     | 7.0205994     |
# | policy_loss        | -0.04688088   |
# | serial_timesteps   | 1680          |
# | time_elapsed       | 2.89          |
# | total_timesteps    | 1680          |
# | value_loss         | 47465320000.0 |
# --------------------------------------
# --------------------------------------
# | approxkl           | 0.0067422264  |
# | clipfrac           | 0.125         |
# | explained_variance | -8.11e-06     |
# | fps                | 634           |
# | n_updates          | 71            |
# | policy_entropy     | 7.0071664     |
# | policy_loss        | -0.042518195  |
# | serial_timesteps   | 1704          |
# | time_elapsed       | 2.93          |
# | total_timesteps    | 1704          |
# | value_loss         | 32170934000.0 |
# --------------------------------------
# --------------------------------------
# | approxkl           | 0.0034556712  |
# | clipfrac           | 0.025         |
# | explained_variance | -8.34e-07     |
# | fps                | 643           |
# | n_updates          | 72            |
# | policy_entropy     | 6.9986076     |
# | policy_loss        | -0.022177804  |
# | serial_timesteps   | 1728          |
# | time_elapsed       | 2.97          |
# | total_timesteps    | 1728          |
# | value_loss         | 67148624000.0 |
# --------------------------------------
# --------------------------------------
# | approxkl           | 0.0023794954  |
# | clipfrac           | 0.025         |
# | explained_variance | -1.91e-06     |
# | fps                | 640           |
# | n_updates          | 73            |
# | policy_entropy     | 6.9899025     |
# | policy_loss        | -0.01357499   |
# | serial_timesteps   | 1752          |
# | time_elapsed       | 3.01          |
# | total_timesteps    | 1752          |
# | value_loss         | 62252240000.0 |
# --------------------------------------
# --------------------------------------
# | approxkl           | 0.0037290535  |
# | clipfrac           | 0.058333337   |
# | explained_variance | -9.06e-06     |
# | fps                | 640           |
# | n_updates          | 74            |
# | policy_entropy     | 6.9892435     |
# | policy_loss        | -0.02650179   |
# | serial_timesteps   | 1776          |
# | time_elapsed       | 3.05          |
# | total_timesteps    | 1776          |
# | value_loss         | 67115045000.0 |
# --------------------------------------
# --------------------------------------
# | approxkl           | 0.006031376   |
# | clipfrac           | 0.09166667    |
# | explained_variance | 4.59e-06      |
# | fps                | 641           |
# | n_updates          | 75            |
# | policy_entropy     | 6.9955626     |
# | policy_loss        | -0.035597786  |
# | serial_timesteps   | 1800          |
# | time_elapsed       | 3.09          |
# | total_timesteps    | 1800          |
# | value_loss         | 57900750000.0 |
# --------------------------------------
# --------------------------------------
# | approxkl           | 0.0033510372  |
# | clipfrac           | 0.06666667    |
# | explained_variance | -3.93e-06     |
# | fps                | 642           |
# | n_updates          | 76            |
# | policy_entropy     | 7.003438      |
# | policy_loss        | -0.027414253  |
# | serial_timesteps   | 1824          |
# | time_elapsed       | 3.13          |
# | total_timesteps    | 1824          |
# | value_loss         | 58273050000.0 |
# --------------------------------------
# --------------------------------------
# | approxkl           | 0.0043346486  |
# | clipfrac           | 0.0625        |
# | explained_variance | 3.87e-06      |
# | fps                | 641           |
# | n_updates          | 77            |
# | policy_entropy     | 7.0099306     |
# | policy_loss        | -0.022403575  |
# | serial_timesteps   | 1848          |
# | time_elapsed       | 3.17          |
# | total_timesteps    | 1848          |
# | value_loss         | 65396500000.0 |
# --------------------------------------
# --------------------------------------
# | approxkl           | 0.0072198845  |
# | clipfrac           | 0.125         |
# | explained_variance | -1.43e-06     |
# | fps                | 634           |
# | n_updates          | 78            |
# | policy_entropy     | 7.0137687     |
# | policy_loss        | -0.035697572  |
# | serial_timesteps   | 1872          |
# | time_elapsed       | 3.21          |
# | total_timesteps    | 1872          |
# | value_loss         | 54791970000.0 |
# --------------------------------------
# --------------------------------------
# | approxkl           | 0.004813927   |
# | clipfrac           | 0.0875        |
# | explained_variance | 5.9e-06       |
# | fps                | 642           |
# | n_updates          | 79            |
# | policy_entropy     | 7.0142303     |
# | policy_loss        | -0.030291036  |
# | serial_timesteps   | 1896          |
# | time_elapsed       | 3.24          |
# | total_timesteps    | 1896          |
# | value_loss         | 63124996000.0 |
# --------------------------------------
# --------------------------------------
# | approxkl           | 0.0044675893  |
# | clipfrac           | 0.07083333    |
# | explained_variance | 2.03e-05      |
# | fps                | 643           |
# | n_updates          | 80            |
# | policy_entropy     | 7.015092      |
# | policy_loss        | -0.033739835  |
# | serial_timesteps   | 1920          |
# | time_elapsed       | 3.28          |
# | total_timesteps    | 1920          |
# | value_loss         | 45820666000.0 |
# --------------------------------------
# --------------------------------------
# | approxkl           | 0.003952976   |
# | clipfrac           | 0.05          |
# | explained_variance | 3.34e-06      |
# | fps                | 643           |
# | n_updates          | 81            |
# | policy_entropy     | 7.01896       |
# | policy_loss        | -0.021489114  |
# | serial_timesteps   | 1944          |
# | time_elapsed       | 3.32          |
# | total_timesteps    | 1944          |
# | value_loss         | 53100265000.0 |
# --------------------------------------
# --------------------------------------
# | approxkl           | 0.006131431   |
# | clipfrac           | 0.075         |
# | explained_variance | 1.22e-05      |
# | fps                | 640           |
# | n_updates          | 82            |
# | policy_entropy     | 7.0112457     |
# | policy_loss        | -0.020880602  |
# | serial_timesteps   | 1968          |
# | time_elapsed       | 3.36          |
# | total_timesteps    | 1968          |
# | value_loss         | 21396386000.0 |
# --------------------------------------
# --------------------------------------
# | approxkl           | 0.005464397   |
# | clipfrac           | 0.09166666    |
# | explained_variance | -1.44e-05     |
# | fps                | 641           |
# | n_updates          | 83            |
# | policy_entropy     | 7.015786      |
# | policy_loss        | -0.032044906  |
# | serial_timesteps   | 1992          |
# | time_elapsed       | 3.4           |
# | total_timesteps    | 1992          |
# | value_loss         | 68380630000.0 |
# --------------------------------------
# --Top 10 individuals found by the RL search
#              x1         x2         x3         x4         x5        score
# 1882   2.384464 -12.614548 -25.667742  14.073005  26.403052  1718.816040
# 1530  -1.089290 -33.249670  -4.801825  36.483887 -12.901120  2627.297607
# 668  -23.790666 -34.321138  29.048103   1.924689 -14.631748  2805.520996
# 874  -10.321067 -28.527731  -7.696656   9.341943  47.600883  3332.710449
# 228    3.719416  37.002110  41.673440 -12.060572  15.432049  3503.271484
# 1214 -41.762796  -8.475709  -3.982884  40.178531  10.443458  3555.212402
# 912  -30.067834 -12.736815  22.309318 -47.735307   5.963784  3878.232910
# 802   29.103568  12.551320  -9.306049 -23.075373  49.168789  4041.198486
# 1748  28.295386  46.911260 -33.537543  -3.374530   8.671704  4212.647949
# 1118 -25.788355  33.451095 -33.594304 -37.547955  14.994186  4547.266602
# ------------------------------- Part II: ES is running and informed by PPO -------------------------------
# --warning: npop_rl and init_pop_rl are passed to ES, so RL-informed ES mode is activated
# The first particle provided by the user: [-29.2412668466568, -58.76119136810303, -24.95589852333069, 17.36648380756378, 5.342550575733185]
# The last particle provided by the user: [-34.46573615074158, 8.928138017654419, -23.303252458572388, -64.75721001625061, 68.81765723228455]
# ##############################################################################
# ES step 60/1200, CX=0.8, MUT=0.2, MU=30, LAMBDA=60, Ncores=1
# ##############################################################################
# Statistics for generation 1
# Best Fitness: 1400.758659
# Best Individual: [-8.79083901361084, -0.22371455186132094, -31.06091560795128, -18.44113085349278, 4.309753449116386]
# Max Strategy: 0.371
# Min Strategy: 0.115
# Average Strategy: 0.249
# ##############################################################################
# ##############################################################################
# ES step 120/1200, CX=0.8, MUT=0.2, MU=30, LAMBDA=60, Ncores=1
# ##############################################################################
# Statistics for generation 2
# Best Fitness: 473.930051
# Best Individual: [11.32633308655251, 2.7754434957378042, -4.259070610323512, 17.277305152304315, -4.6147792022901655]
# Max Strategy: 0.38
# Min Strategy: 0.134
# Average Strategy: 0.256
# ##############################################################################
# ##############################################################################
# ES step 180/1200, CX=0.8, MUT=0.2, MU=30, LAMBDA=60, Ncores=1
# ##############################################################################
# Statistics for generation 3
# Best Fitness: 706.510267
# Best Individual: [1.2615690365549956, -9.842765820185903, -19.727581687689355, 13.108061210414041, 6.858565741523479]
# Max Strategy: 0.425
# Min Strategy: 0.123
# Average Strategy: 0.243
# ##############################################################################
# ##############################################################################
# ES step 240/1200, CX=0.8, MUT=0.2, MU=30, LAMBDA=60, Ncores=1
# ##############################################################################
# Statistics for generation 4
# Best Fitness: 527.171007
# Best Individual: [4.0678718912276155, 7.682834525080757, 11.53586338357279, 10.343274762953163, -14.544346051768485]
# Max Strategy: 0.41
# Min Strategy: 0.064
# Average Strategy: 0.231
# ##############################################################################
# ##############################################################################
# ES step 300/1200, CX=0.8, MUT=0.2, MU=30, LAMBDA=60, Ncores=1
# ##############################################################################
# Statistics for generation 5
# Best Fitness: 216.982746
# Best Individual: [1.1721287641838496, -13.916086331143665, 4.372773503015036, -0.5311950929767146, 1.5962721922310976]
# Max Strategy: 0.433
# Min Strategy: 0.049
# Average Strategy: 0.235
# ##############################################################################
# ##############################################################################
# ES step 360/1200, CX=0.8, MUT=0.2, MU=30, LAMBDA=60, Ncores=1
# ##############################################################################
# Statistics for generation 6
# Best Fitness: 213.15762
# Best Individual: [6.5356131544987015, 7.972088334200304, -8.541514285135342, 3.4558476311834627, 4.68922590199325]
# Max Strategy: 0.418
# Min Strategy: 0.07
# Average Strategy: 0.244
# ##############################################################################
# ##############################################################################
# ES step 420/1200, CX=0.8, MUT=0.2, MU=30, LAMBDA=60, Ncores=1
# ##############################################################################
# Statistics for generation 7
# Best Fitness: 116.205021
# Best Individual: [2.4749970914713204, 0.7397840036260908, -5.900923844439262, 7.48466919401986, -4.323303710925092]
# Max Strategy: 0.38
# Min Strategy: 0.15
# Average Strategy: 0.244
# ##############################################################################
# ##############################################################################
# ES step 480/1200, CX=0.8, MUT=0.2, MU=30, LAMBDA=60, Ncores=1
# ##############################################################################
# Statistics for generation 8
# Best Fitness: 107.702252
# Best Individual: [2.35853088871351, 0.6843389372120023, -5.708905281338468, 7.083183630076327, -4.3483530199141125]
# Max Strategy: 0.404
# Min Strategy: 0.137
# Average Strategy: 0.244
# ##############################################################################
# ##############################################################################
# ES step 540/1200, CX=0.8, MUT=0.2, MU=30, LAMBDA=60, Ncores=1
# ##############################################################################
# Statistics for generation 9
# Best Fitness: 74.291437
# Best Individual: [-0.23784078150418275, -8.14414772825191, -2.367234298169222, -0.39588931462877763, 1.4653328827879042]
# Max Strategy: 0.332
# Min Strategy: 0.109
# Average Strategy: 0.236
# ##############################################################################
# ##############################################################################
# ES step 600/1200, CX=0.8, MUT=0.2, MU=30, LAMBDA=60, Ncores=1
# ##############################################################################
# Statistics for generation 10
# Best Fitness: 31.886031
# Best Individual: [-0.23608335479092496, -0.31498190904051315, -0.3425825425837019, -5.351277013456398, -1.7255588797286587]
# Max Strategy: 0.347
# Min Strategy: 0.093
# Average Strategy: 0.239
# ##############################################################################
# ##############################################################################
# ES step 660/1200, CX=0.8, MUT=0.2, MU=30, LAMBDA=60, Ncores=1
# ##############################################################################
# Statistics for generation 11
# Best Fitness: 31.091016
# Best Individual: [0.6374508200696228, 0.1259989609597617, -1.897476698895133, -5.066821359450992, 1.1813976536619613]
# Max Strategy: 0.374
# Min Strategy: 0.07
# Average Strategy: 0.219
# ##############################################################################
# ##############################################################################
# ES step 720/1200, CX=0.8, MUT=0.2, MU=30, LAMBDA=60, Ncores=1
# ##############################################################################
# Statistics for generation 12
# Best Fitness: 8.111306
# Best Individual: [-0.2610398768219005, -1.5800132988775917, -1.4353923770877277, 0.7560933076065224, 1.707247501476609]
# Max Strategy: 0.351
# Min Strategy: 0.115
# Average Strategy: 0.241
# ##############################################################################
# ##############################################################################
# ES step 780/1200, CX=0.8, MUT=0.2, MU=30, LAMBDA=60, Ncores=1
# ##############################################################################
# Statistics for generation 13
# Best Fitness: 30.207266
# Best Individual: [-2.2932451305174197, -2.447938245093323, -2.7875534481566, -3.01378348234664, -1.4500160327374716]
# Max Strategy: 0.339
# Min Strategy: 0.128
# Average Strategy: 0.236
# ##############################################################################
# ##############################################################################
# ES step 840/1200, CX=0.8, MUT=0.2, MU=30, LAMBDA=60, Ncores=1
# ##############################################################################
# Statistics for generation 14
# Best Fitness: 4.064831
# Best Individual: [0.2553358142042124, 0.4224524231104473, -0.6576830387894119, 0.6795425656943039, 1.710802145138001]
# Max Strategy: 0.392
# Min Strategy: 0.126
# Average Strategy: 0.245
# ##############################################################################
# ##############################################################################
# ES step 900/1200, CX=0.8, MUT=0.2, MU=30, LAMBDA=60, Ncores=1
# ##############################################################################
# Statistics for generation 15
# Best Fitness: 8.287346
# Best Individual: [0.3147035493696766, 0.0299215813417767, -2.6385539290819304, 0.2741468735609986, 1.072515427053313]
# Max Strategy: 0.332
# Min Strategy: 0.158
# Average Strategy: 0.247
# ##############################################################################
# ##############################################################################
# ES step 960/1200, CX=0.8, MUT=0.2, MU=30, LAMBDA=60, Ncores=1
# ##############################################################################
# Statistics for generation 16
# Best Fitness: 6.31317
# Best Individual: [0.39227139882153667, 1.7244103016115375, 0.18124238479175858, -0.22996258770496303, -1.7606733139803097]
# Max Strategy: 0.34
# Min Strategy: 0.153
# Average Strategy: 0.243
# ##############################################################################
# ##############################################################################
# ES step 1020/1200, CX=0.8, MUT=0.2, MU=30, LAMBDA=60, Ncores=1
# ##############################################################################
# Statistics for generation 17
# Best Fitness: 5.256921
# Best Individual: [-0.03392271472623361, 2.0169970909999475, 0.3593391732090807, 0.43322172909515816, 0.9331060415512266]
# Max Strategy: 0.35
# Min Strategy: 0.12
# Average Strategy: 0.239
# ##############################################################################
# ##############################################################################
# ES step 1080/1200, CX=0.8, MUT=0.2, MU=30, LAMBDA=60, Ncores=1
# ##############################################################################
# Statistics for generation 18
# Best Fitness: 4.442651
# Best Individual: [0.8229305120539185, 0.22288904685821948, -1.9113819472943516, 0.13626073109697556, 0.2093054161687917]
# Max Strategy: 0.432
# Min Strategy: 0.178
# Average Strategy: 0.258
# ##############################################################################
# ##############################################################################
# ES step 1140/1200, CX=0.8, MUT=0.2, MU=30, LAMBDA=60, Ncores=1
# ##############################################################################
# Statistics for generation 19
# Best Fitness: 3.492376
# Best Individual: [0.7891618852774449, 0.7566157218578475, -1.411068951724443, 0.48739854993751186, 0.2616466108997804]
# Max Strategy: 0.387
# Min Strategy: 0.156
# Average Strategy: 0.25
# ##############################################################################
# ##############################################################################
# ES step 1200/1200, CX=0.8, MUT=0.2, MU=30, LAMBDA=60, Ncores=1
# ##############################################################################
# Statistics for generation 20
# Best Fitness: 1.502063
# Best Individual: [0.9774850808356113, 0.3146801262371347, 0.046053455938404264, -0.5546979087845341, 0.37114900536229145]
# Max Strategy: 0.421
# Min Strategy: 0.114
# Average Strategy: 0.261
# ##############################################################################
# ------------------------ ES Summary --------------------------
# Best fitness (y) found: 1.5020629401000447
# Best individual (x) found: [0.9774850808356113, 0.3146801262371347, 0.046053455938404264, -0.5546979087845341, 0.37114900536229145]
# --------------------------------------------------------------
# ************************* PPO-ES Summary *************************
# Best fitness (y) found: [0.9774850808356113, 0.3146801262371347, 0.046053455938404264, -0.5546979087845341, 0.37114900536229145]
# Best individual (x) found: 1.5020629401000447
# ******************************************************************

# %%
import os
import numpy as np
from mpi4py import MPI
from pathlib import Path
from scipy.optimize import minimize
from simsopt.util import MpiPartition
from simsopt._core.derivative import Derivative
from simsopt.mhd import Vmec, QuasisymmetryRatioResidual
from simsopt._core.finite_difference import MPIFiniteDifference
from simsopt.field import BiotSavart, Current, coils_via_symmetries
from simsopt.objectives import SquaredFlux, QuadraticPenalty, LeastSquaresProblem
from simsopt.geo import (CurveLength, CurveCurveDistance, MeanSquaredCurvature,
                        LpCurveCurvature, ArclengthVariation, curves_to_vtk, create_equally_spaced_curves)
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-3-65b56f846ba9> in <module>
#       1 import os
#       2 import numpy as np
# ----> 3 from mpi4py import MPI
#       4 from pathlib import Path
#       5 from scipy.optimize import minimize
#
# ModuleNotFoundError: No module named 'mpi4py'
